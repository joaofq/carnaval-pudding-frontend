# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\gabri\2019-pesquisa-com-foliao-do-carnaval-de-belo-horizonte_v5.csv', sep=';')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1133 entries, 0 to 1132
# Data columns (total 69 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          1133 non-null   int64
#  1   MORADOR                     1133 non-null   object
#  2   NUMERO_CONTROLE             1133 non-null   int64
#  3   BLOCO                       1133 non-null   object
#  4   DT_VISITA                   1133 non-null   object
#  5   TEMPO_TOTAL_ENTREV          1133 non-null   object
#  6   IDADE                       1133 non-null   int64
#  7   PAIS                        1133 non-null   object
#  8   ESTADO                      1133 non-null   object
#  9   CIDADE                      1133 non-null   object
#  10  OUTRA_CIDADE                172 non-null    object
#  11  BAIRRO_BH                   757 non-null    object
#  12  REGIAO_BH                   757 non-null    object
# ...

# %%
df.BLOCO.unique()
# Out:
# array(['entao_brilha', 'lindo_bloco_do_amor', 'bloco_havayanas_usadas',
#        'quando_come_se_lambuza', 'tchanzinho_zona_norte', 'funk_you',
#        'monobloco', 'bloco_volta_belchior', 'bloco_da_calixto',
#        'chama_o_sindico', 'garotas_solteiras', 'juventude_bronzeada',
#        'magnolia', 'alo_abacaxi', 'bloco_angola_janga', 'pena_de_pavao',
#        'sexta_ninguem_sabe', 'beico_do_wando', 'ordinarios',
#        'baianas_ozadas'], dtype=object)

# %%
df=df[df['BLOCO'].isin(['entao_brilha', 'bloco_havayanas_usadas',
       'quando_come_se_lambuza', 'tchanzinho_zona_norte', 'funk_you',
       'monobloco', 'juventude_bronzeada', 'bloco_angola_janga',  'baianas_ozadas'])]

# %%
df_novo=df.drop(df[df['AVAL_GERAL']=='nr_nao_sabe'].index)

# %%
df_novo['AVAL_GERAL']=df_novo['AVAL_GERAL'].astype(float)

# %%
df_novo.pivot_table(index='BLOCO', values='AVAL_GERAL', aggfunc='mean').plot(kind='bar', figsize=(12, 10))
plt.savefig('barras2019.png')
